# %% [markdown]
# <a href="https://colab.research.google.com/github/inandout66/data-science-bootcamp/blob/main/notatnikAW_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.0'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
fig = plt.figure()
fig.show()

# %%
_ = plt.plot([0, 1], [0, 3]) # wartości na osi X 0 1 i Y 0 3, przypisanie tego do zmiennej tymczasowej _ powoduje brak napisu

# %%
plt.plot([0, 1], [0, 3], label='line', color='green') #parametr label oznacza opis linii, parametr color kolor
plt.xlabel('oś x') #opis osi X
plt.ylabel('oś y') #opis osi x
plt.title('Wykres liniowy') #tytuł wykresu
plt.legend() #wyświetla wykres z legendą

# %%
plt.plot([0, 1, 2], [0, 3, 2], label='line', color='green') #parametr label oznacza opis linii, parametr color kolor
plt.xlabel('oś x') #opis osi X
plt.ylabel('oś y') #opis osi x
plt.title('Wykres liniowy') #tytuł wykresu
plt.legend() #wyświetla wykres z legendą

# %%
x = np.arange(-3, 3, 0.1)
x_sin = np.sin(x)
x_cos = np.cos(x)

plt.plot(x,x_sin)
plt.plot(x,x_cos)

# %% [markdown]
# Wiele wykresów na raz

# %%
plt.subplot(121) #1 wiersz, 2 ilość kolumn, numer wykresu tutaj 1
plt.plot([0, 1, 2], [3, 2, 5])
plt.subplot(122) #1 wiersz, 2 kolumny, numer wykresu tutaj 2
plt.plot([0, 1, 2], [3, 1, 4], 'r--') #r-- czerwona linia przerywana

# %%
fig = plt.figure(figsize=(12,8))

plt.subplot(131) #1 wiersz, 3 ilość kolumn, numer wykresu tutaj 1
plt.plot([0, 1, 2], [3, 2, 5])
plt.subplot(132) #1 wiersz, 3 kolumny, numer wykresu tutaj 2
plt.plot([0, 1, 2], [3, 1, 4], 'r--') #r-- czerwona linia przerywana
plt.subplot(133) #1 wiersz, 3 kolumny, numer wykresu tutaj 3
plt.plot([0, 1, 2], [3, 1, 4], 'ro') #ro czerwony wykres punktowy

# %% [markdown]
# Wykresy słupkowe

# %%
plt.bar(x=[0, 1, 2, 3], height=[1.2, 3.2, 1.2, 5.2])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x=['a', 'b', 'c', 'd'], height=[1.2, 3.2, 1.2, 5.2])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(y=['a', 'b', 'c', 'd'], width=[1.2, 3.2, 1.2, 5.2])
# Out:
# <BarContainer object of 4 artists>

# %%
x1 = np.random.randn(300)
x2 = np.random.randn(300)

plt.scatter(x=x1, y=x2)

# %%
x3 = np.random.randn(300) * 50

plt.scatter(x=x1, y=x2, s=x3)
# Out:
# /usr/local/lib/python3.11/dist-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.scatter(x=x1, y=x2, s=x3, alpha=0.5)
# Out:
# /usr/local/lib/python3.11/dist-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# wyświetlania obrazów
